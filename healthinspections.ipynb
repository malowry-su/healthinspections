# %%
import requests
import json
url = 'https://health.data.ny.gov/resource/f285-x9ha.json'
response = requests.get(url)
joints = response.json()

def get_establishments(name, establishments):
    name = name.lower()
    ret_val = []
    for establishment in establishments:
        if establishment["operation_name"].lower() == name:
            ret_val.append(establishment)
    return ret_val
"""
Coded by ....
some description about the function
params:
    score1
    score2
return: total
"""
def calculate_score(score, score2):
    #do a bunch of magic
    return total

total = calculate_score(3, 5)
total
# Out:
# 0
# 2

# %%
response.ok
# Out:
# True

# %%
response.text
# Out:
# '[{":@computed_region_43an_4dx5":"730",":@computed_region_9yqb_tdyd":"2132","address":"7575 Buckley ROAD,  North Syracuse","city":"North Syracuse","county":"ONONDAGA","date":"2017-02-09T00:00:00.000","description":"Food Service Establishment - Restaurant","facility":"San Remo Pizza                      ","facility_address":"7575 Buckley ROAD","food_service_facility_state":"NY","inspection_comments":"Reinspection this date for violations cited during an inspection on 01/19/17. The majority of violations have been corrected at this time. Recommend abatement.","inspection_type":"Re-Inspection","local_health_department":"Onondaga County","location1":{"type":"Point","coordinates":[-76.170444,43.136533]},"municipality":"CLAY","nys_health_operation_id":"554475","nysdoh_gazetteer_1980":"335200","operation_name":"San Remo Pizza","perm_operator_first_name":"Adam","perm_operator_last_name":"Duffy","permit_expiration_date":"2018-01-31T00:00:00.000","permitted_corp_name":"Adamo\'s Pizzeria Corp."
# ...
